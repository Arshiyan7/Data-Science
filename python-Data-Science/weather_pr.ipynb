# %%
import pandas as pd 
import matplotlib.pyplot as plt 
weather = pd.read_csv("Weather-Data.csv")
weather
# Out:
#          Date  Temperature   Humidity  Wind Speed  Rain          Cities
# 0    1/1/2024            22        60          15   0.0        New York
# 1    1/2/2024            24        55          12   0.0     Los Angeles
# 2    1/3/2024            23        58          10   0.0         Chicago
# 3    1/4/2024            20        65          18   0.0         Houston
# 4    1/5/2024            21        63          16   1.2         Phoenix
# ..        ...           ...       ...         ...   ...             ...
# 86  3/27/2024            22        60          16   0.3         Augusta
# 87  3/28/2024            23        61          13   0.0    Grand Rapids
# 88  3/29/2024            21        65          14   0.0          Mobile
# 89  3/30/2024            22        62          15   0.0  Salt Lake City
# 90  3/31/2024            23        60          16   0.0     Tallahassee
#
# [91 rows x 6 columns]

# %%
#make a copy of df (Good practice)
copy_weather = weather.copy()
copy_weather
# Out:
#          Date  Temperature   Humidity  Wind Speed  Rain          Cities
# 0    1/1/2024            22        60          15   0.0        New York
# 1    1/2/2024            24        55          12   0.0     Los Angeles
# 2    1/3/2024            23        58          10   0.0         Chicago
# 3    1/4/2024            20        65          18   0.0         Houston
# 4    1/5/2024            21        63          16   1.2         Phoenix
# ..        ...           ...       ...         ...   ...             ...
# 86  3/27/2024            22        60          16   0.3         Augusta
# 87  3/28/2024            23        61          13   0.0    Grand Rapids
# 88  3/29/2024            21        65          14   0.0          Mobile
# 89  3/30/2024            22        62          15   0.0  Salt Lake City
# 90  3/31/2024            23        60          16   0.0     Tallahassee
#
# [91 rows x 6 columns]

# %%
#check datatypes and conversion 
print(copy_weather.dtypes)
#checking datetime and making sure it's datetime rather than object/string if no then convert it to datetime:
copy_weather['Date'] = pd.to_datetime(copy_weather['Date'])
copy_weather['Date'].dtype
# Out:
# Date             object
# Temperature       int64
# Humidity          int64
# Wind Speed        int64
# Rain            float64
# Cities           object
# dtype: object
# dtype('<M8[ns]')

# %%
#basic info of dataset 
print("First 5 rows: ",copy_weather.head(5))
print("\nlast five rows: \n",copy_weather.tail(5))
print("\nStats: \n",copy_weather.describe())
# Out:
# First 5 rows:          Date  Temperature   Humidity  Wind Speed  Rain       Cities
# 0 2024-01-01            22        60          15   0.0     New York
# 1 2024-01-02            24        55          12   0.0  Los Angeles
# 2 2024-01-03            23        58          10   0.0      Chicago
# 3 2024-01-04            20        65          18   0.0      Houston
# 4 2024-01-05            21        63          16   1.2      Phoenix
#
# last five rows:
#           Date  Temperature   Humidity  Wind Speed  Rain          Cities
# 86 2024-03-27            22        60          16   0.3         Augusta
# 87 2024-03-28            23        61          13   0.0    Grand Rapids
# 88 2024-03-29            21        65          14   0.0          Mobile
# 89 2024-03-30            22        62          15   0.0  Salt Lake City
# 90 2024-03-31            23        60          16   0.0     Tallahassee
#
# Stats:
#                        Date  Temperature    Humidity  Wind Speed       Rain
# count                   91     91.000000  91.000000   91.000000  91.000000
# mean   2024-02-15 00:00:00     21.879121  62.560440   14.714286   0.076923
# min    2024-01-01 00:00:00     18.000000  55.000000   10.000000   0.000000
# 25%    2024-01-23 12:00:00     21.000000  60.000000   13.000000   0.000000
# 50%    2024-02-15 00:00:00     22.000000  62.000000   15.000000   0.000000
# 75%    2024-03-08 12:00:00     23.000000  65.000000   16.000000   0.000000
# max    2024-03-31 00:00:00     25.000000  73.000000   20.000000   1.200000
# std                    NaN      1.769087   4.096635    2.114951   0.214516

# %%
import matplotlib.pyplot as plt

# Plot for Temperature
plt.figure(figsize=(10, 6))
copy_weather['Temperature '].hist(bins=20, color='red', edgecolor='black')
plt.title('Temperature Distribution', fontsize=14)
plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.show()

# Plot for Humidity
plt.figure(figsize=(10, 6))
copy_weather['Humidity'].hist(bins=20, color='blue', edgecolor='black')
plt.title('Humidity Distribution', fontsize=14)
plt.xlabel('Humidity (%)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.show()

# Plot for Wind Speed
plt.figure(figsize=(10, 6))
copy_weather['Wind Speed'].hist(bins=20, color='green', edgecolor='black')
plt.title('Wind Speed Distribution', fontsize=14)
plt.xlabel('Wind Speed (km/h)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.show()

# Plot for Rain
plt.figure(figsize=(10, 6))
copy_weather['Rain'].hist(bins=20, color='purple', edgecolor='black')
plt.title('Rain Distribution', fontsize=14)
plt.xlabel('Rain (mm)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.show()

# %%
#check temperatures
max_temperature = copy_weather['Temperature '].max()
print("Maximum temperature recorded is: ",max_temperature)
Hottest_days = copy_weather[copy_weather['Temperature ']>24]
print("Hottest Temperature record is: \n",Hottest_days)
hot_and_humid = copy_weather[(copy_weather['Temperature '] > 30) & (copy_weather['Humidity'] > 70)]
print(hot_and_humid)
# Out:
# Maximum temperature recorded is:  25
# Hottest Temperature record is:
#           Date  Temperature   Humidity  Wind Speed  Rain      Cities
# 10 2024-01-11            25        60          15   0.0      Austin
# 28 2024-01-29            25        55          12   0.0  Louisville
# 53 2024-02-23            25        55          13   0.0    Honolulu
# 64 2024-03-05            25        55          12   0.0  Pittsburgh
# 76 2024-03-17            25        55          13   0.0     Madison
# Empty DataFrame
# Columns: [Date, Temperature , Humidity, Wind Speed, Rain, Cities]
# Index: []

# %%
#grouping data
stats = copy_weather.groupby('Humidity').agg({
    'Temperature ': ['mean', 'max'],
    'Wind Speed': ['mean', 'min']
})
print(stats)
# Out:
#          Temperature      Wind Speed
#                  mean max       mean min
# Humidity
# 55          24.800000  25  12.400000  12
# 56          24.000000  24  11.000000  11
# 58          23.833333  24  14.500000  10
# 59          23.500000  24  14.500000  13
# 60          22.700000  25  15.000000  11
# 61          22.428571  23  14.857143  13
# 62          22.307692  23  14.692308  12
# 63          21.600000  23  14.800000  12
# 64          21.714286  23  14.142857  13
# 65          20.666667  21  15.166667  12
# 66          20.250000  21  14.250000  14
# 67          20.000000  20  11.000000  11
# 68          20.000000  20  15.500000  14
# 69          18.750000  19  16.250000  12
# 70          19.000000  19  17.000000  14
# 71          19.000000  19  15.000000  15
# 72          18.000000  18  16.500000  14
# 73          18.000000  18  17.000000  17

# %%
by_Day = copy_weather.resample('D', on='Date').mean(numeric_only=True)
by_Week = copy_weather.resample('W', on='Date').mean(numeric_only=True)
by_month = copy_weather.resample('ME', on='Date').mean(numeric_only=True)

print(f'Data by day:\n{by_Day}\nData by week:\n{by_Week}\nData by month:\n{by_month}')
# Out:
# Data by day:
#             Temperature   Humidity  Wind Speed  Rain
# Date
# 2024-01-01          22.0      60.0        15.0   0.0
# 2024-01-02          24.0      55.0        12.0   0.0
# 2024-01-03          23.0      58.0        10.0   0.0
# 2024-01-04          20.0      65.0        18.0   0.0
# 2024-01-05          21.0      63.0        16.0   1.2
# ...                  ...       ...         ...   ...
# 2024-03-27          22.0      60.0        16.0   0.3
# 2024-03-28          23.0      61.0        13.0   0.0
# 2024-03-29          21.0      65.0        14.0   0.0
# 2024-03-30          22.0      62.0        15.0   0.0
# 2024-03-31          23.0      60.0        16.0   0.0
#
# [91 rows x 4 columns]
# Data by week:
#             Temperature    Humidity  Wind Speed      Rain
# Date
# 2024-01-07     21.571429  61.857143   14.571429  0.171429
# 2024-01-14     22.142857  63.142857   13.571429  0.114286
# 2024-01-21     21.285714  64.285714   16.142857  0.171429
# 2024-01-28     21.000000  65.000000   15.857143  0.057143
# 2024-02-04     21.428571  63.000000   14.571429  0.100000
# 2024-02-11     20.857143  65.714286   15.000000  0.157143
# 2024-02-18     21.428571  63.142857   13.857143  0.042857
# 2024-02-25     22.857143  60.857143   14.428571  0.000000
# 2024-03-03     22.000000  62.000000   15.571429  0.042857
# 2024-03-10     22.000000  62.142857   13.714286  0.042857
# 2024-03-17     22.857143  59.714286   14.571429  0.042857
# 2024-03-24     22.428571  61.000000   14.428571  0.014286
# 2024-03-31     22.571429  61.428571   15.000000  0.042857
# Data by month:
#             Temperature    Humidity  Wind Speed      Rain
# Date
# 2024-01-31     21.677419  63.096774   14.838710  0.132258
# 2024-02-29     21.517241  63.413793   14.896552  0.065517
# 2024-03-31     22.419355  61.225806   14.419355  0.032258

# %%
copy_weather['wind_chill'] = copy_weather['Temperature '].apply(lambda x: x - 0.5 if x > 20 else x)
print(copy_weather.head())
# Out:
#         Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 0 2024-01-01            22        60          15   0.0     New York
# 1 2024-01-02            24        55          12   0.0  Los Angeles
# 2 2024-01-03            23        58          10   0.0      Chicago
# 3 2024-01-04            20        65          18   0.0      Houston
# 4 2024-01-05            21        63          16   1.2      Phoenix
#
#    wind_chill
# 0        21.5
# 1        23.5
# 2        22.5
# 3        20.0
# 4        20.5

# %%
#plottings: 
print("Plot 1:")
Temperature_overTime = copy_weather.groupby('Date')['Temperature '].mean()
Temperature_overTime.plot(kind='hist',
                          figsize=(10,6),
                          xlabel='Date',
                          ylabel='Temperature',
                          title="Temperature over time",
                          color='navy',edgecolor='white')
plt.show()
print("\nPlot 2:")
copy_weather.plot.hist(
    x='Humidity',
    y='Temperature ',
    figsize=(10, 6),
    xlabel='Humidity',
    ylabel='Temperature',
    title='Humidity vs Temperature',
    edgecolor='Black'
)

plt.show()
# Out:
# Plot 1:
# Plot 2:

# %%
by_cities = copy_weather.groupby('Cities')
for city, data in by_cities:
    print(f"Weather data for {city}:")
    print(data)
    print("\n" + "-"*50 + "\n")
# Out:
# Weather data for Albuquerque:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 31 2024-02-01            21        63          16   0.0  Albuquerque
#
#     wind_chill
# 31        20.5
#
# --------------------------------------------------
#
# Weather data for Anaheim:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 54 2024-02-24            23        60          18   0.0  Anaheim        22.5
#
# --------------------------------------------------
#
# Weather data for Anchorage:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 67 2024-03-08            21        64          15   0.0  Anchorage        20.5
#
# --------------------------------------------------
#
# Weather data for Arlington:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 46 2024-02-16            20        65          15   0.0  Arlington        20.0
#
# --------------------------------------------------
#
# Weather data for Atlanta:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 37 2024-02-07            21        66          14   0.0  Atlanta        20.5
#
# --------------------------------------------------
#
# Weather data for Augusta:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 86 2024-03-27            22        60          16   0.3  Augusta        21.5
#
# --------------------------------------------------
#
# Weather data for Aurora:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 52 2024-02-22            24        59          16   0.0  Aurora        23.5
#
# --------------------------------------------------
#
# Weather data for Austin:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 10 2024-01-11            25        60          15   0.0  Austin        24.5
#
# --------------------------------------------------
#
# Weather data for Bakersfield:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 51 2024-02-21            21        65          12   0.0  Bakersfield
#
#     wind_chill
# 51        20.5
#
# --------------------------------------------------
#
# Weather data for Baltimore:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 29 2024-01-30            23        59          13   0.5  Baltimore        22.5
#
# --------------------------------------------------
#
# Weather data for Baton Rouge:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 82 2024-03-23            21        64          13   0.0  Baton Rouge
#
#     wind_chill
# 82        20.5
#
# --------------------------------------------------
#
# Weather data for Boston:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 20 2024-01-21            21        65          15   0.0  Boston        20.5
#
# --------------------------------------------------
#
# Weather data for Buffalo:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 74 2024-03-15            21        62          17   0.0  Buffalo        20.5
#
# --------------------------------------------------
#
# Weather data for Chandler:
#          Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 75 2024-03-16            23        59          14   0.3  Chandler        22.5
#
# --------------------------------------------------
#
# Weather data for Charlotte:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 15 2024-01-16            22        63          18   0.2  Charlotte        21.5
#
# --------------------------------------------------
#
# Weather data for Chicago:
#         Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 2 2024-01-03            23        58          10   0.0  Chicago        22.5
#
# --------------------------------------------------
#
# Weather data for Chula Vista:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 73 2024-03-14            22        60          16   0.0  Chula Vista
#
#     wind_chill
# 73        21.5
#
# --------------------------------------------------
#
# Weather data for Cincinnati:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 63 2024-03-04            24        59          13   0.0  Cincinnati
#
#     wind_chill
# 63        23.5
#
# --------------------------------------------------
#
# Weather data for Cleveland:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 49 2024-02-19            22        63          13   0.0  Cleveland        21.5
#
# --------------------------------------------------
#
# Weather data for Columbus:
#          Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 13 2024-01-14            24        56          11   0.0  Columbus        23.5
#
# --------------------------------------------------
#
# Weather data for Corpus Christi:
#          Date  Temperature   Humidity  Wind Speed  Rain          Cities  \
# 56 2024-02-26            21        63          16   0.3  Corpus Christi
#
#     wind_chill
# 56        20.5
#
# --------------------------------------------------
#
# Weather data for Dallas:
#         Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 8 2024-01-09            20        67          11   0.0  Dallas        20.0
#
# --------------------------------------------------
#
# Weather data for Denver:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 18 2024-01-19            22        61          16   0.0  Denver        21.5
#
# --------------------------------------------------
#
# Weather data for Des Moines:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 84 2024-03-25            23        63          16   0.0  Des Moines
#
#     wind_chill
# 84        22.5
#
# --------------------------------------------------
#
# Weather data for Detroit:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 23 2024-01-24            19        70          19   0.0  Detroit        19.0
#
# --------------------------------------------------
#
# Weather data for Durham:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 72 2024-03-13            24        58          15   0.0  Durham        23.5
#
# --------------------------------------------------
#
# Weather data for El Paso:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 21 2024-01-22            23        62          12   0.0  El Paso        22.5
#
# --------------------------------------------------
#
# Weather data for Fort Worth:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 12 2024-01-13            23        62          12   0.0  Fort Worth
#
#     wind_chill
# 12        22.5
#
# --------------------------------------------------
#
# Weather data for Fresno:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 33 2024-02-03            18        72          14   0.0  Fresno        18.0
#
# --------------------------------------------------
#
# Weather data for Glendale:
#          Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 80 2024-03-21            22        61          14   0.0  Glendale        21.5
#
# --------------------------------------------------
#
# Weather data for Grand Rapids:
#          Date  Temperature   Humidity  Wind Speed  Rain        Cities  \
# 87 2024-03-28            23        61          13   0.0  Grand Rapids
#
#     wind_chill
# 87        22.5
#
# --------------------------------------------------
#
# Weather data for Greensboro:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 65 2024-03-06            22        60          14   0.0  Greensboro
#
#     wind_chill
# 65        21.5
#
# --------------------------------------------------
#
# Weather data for Henderson:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 60 2024-03-01            21        63          13   0.0  Henderson        20.5
#
# --------------------------------------------------
#
# Weather data for Hialeah:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 81 2024-03-22            23        59          15   0.0  Hialeah        22.5
#
# --------------------------------------------------
#
# Weather data for Honolulu:
#          Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 53 2024-02-23            25        55          13   0.0  Honolulu        24.5
#
# --------------------------------------------------
#
# Weather data for Houston:
#         Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 3 2024-01-04            20        65          18   0.0  Houston        20.0
#
# --------------------------------------------------
#
# Weather data for Indianapolis:
#          Date  Temperature   Humidity  Wind Speed  Rain        Cities  \
# 16 2024-01-17            24        59          13   0.0  Indianapolis
#
#     wind_chill
# 16        23.5
#
# --------------------------------------------------
#
# Weather data for Irvine:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 70 2024-03-11            22        63          13   0.0  Irvine        21.5
#
# --------------------------------------------------
#
# Weather data for Jacksonville:
#          Date  Temperature   Humidity  Wind Speed  Rain        Cities  \
# 11 2024-01-12            22        61          14   0.3  Jacksonville
#
#     wind_chill
# 11        21.5
#
# --------------------------------------------------
#
# Weather data for Kansas City:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 35 2024-02-05            23        62          16   0.0  Kansas City
#
#     wind_chill
# 35        22.5
#
# --------------------------------------------------
#
# Weather data for Laredo:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 77 2024-03-18            22        63          15   0.0  Laredo        21.5
#
# --------------------------------------------------
#
# Weather data for Las Vegas:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 26 2024-01-27            20        66          14   0.0  Las Vegas        20.0
#
# --------------------------------------------------
#
# Weather data for Lexington:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 58 2024-02-28            23        59          17   0.0  Lexington        22.5
#
# --------------------------------------------------
#
# Weather data for Lincoln:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 66 2024-03-07            23        62          16   0.3  Lincoln        22.5
#
# --------------------------------------------------
#
# Weather data for Long Beach:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 41 2024-02-11            23        60          11   0.0  Long Beach
#
#     wind_chill
# 41        22.5
#
# --------------------------------------------------
#
# Weather data for Los Angeles:
#         Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 1 2024-01-02            24        55          12   0.0  Los Angeles
#
#    wind_chill
# 1        23.5
#
# --------------------------------------------------
#
# Weather data for Louisville:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 28 2024-01-29            25        55          12   0.0  Louisville
#
#     wind_chill
# 28        24.5
#
# --------------------------------------------------
#
# Weather data for Madison:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 76 2024-03-17            25        55          13   0.0  Madison        24.5
#
# --------------------------------------------------
#
# Weather data for Memphis:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 27 2024-01-28            24        58          18   0.0  Memphis        23.5
#
# --------------------------------------------------
#
# Weather data for Mesa:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 36 2024-02-06            20        68          17   0.1   Mesa        20.0
#
# --------------------------------------------------
#
# Weather data for Miami:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 40 2024-02-10            18        69          19   1.0  Miami        18.0
#
# --------------------------------------------------
#
# Weather data for Milwaukee:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 30 2024-01-31            22        62          14   0.0  Milwaukee        21.5
#
# --------------------------------------------------
#
# Weather data for Minneapolis:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 44 2024-02-14            22        61          17   0.0  Minneapolis
#
#     wind_chill
# 44        21.5
#
# --------------------------------------------------
#
# Weather data for Mobile:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 88 2024-03-29            21        65          14   0.0  Mobile        20.5
#
# --------------------------------------------------
#
# Weather data for Montgomery:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 85 2024-03-26            24        59          15   0.0  Montgomery
#
#     wind_chill
# 85        23.5
#
# --------------------------------------------------
#
# Weather data for Nashville:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 22 2024-01-23            18        73          17   0.1  Nashville        18.0
#
# --------------------------------------------------
#
# Weather data for New Orleans:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 47 2024-02-17            21        64          16   0.0  New Orleans
#
#     wind_chill
# 47        20.5
#
# --------------------------------------------------
#
# Weather data for New York:
#         Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 0 2024-01-01            22        60          15   0.0  New York        21.5
#
# --------------------------------------------------
#
# Weather data for Newark:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 71 2024-03-12            23        61          14   0.0  Newark        22.5
#
# --------------------------------------------------
#
# Weather data for Oakland:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 43 2024-02-13            24        58          10   0.0  Oakland        23.5
#
# --------------------------------------------------
#
# Weather data for Oklahoma City:
#          Date  Temperature   Humidity  Wind Speed  Rain         Cities  \
# 24 2024-01-25            22        64          15   0.3  Oklahoma City
#
#     wind_chill
# 24        21.5
#
# --------------------------------------------------
#
# Weather data for Omaha:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 39 2024-02-09            19        71          15   0.0  Omaha        19.0
#
# --------------------------------------------------
#
# Weather data for Orlando:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 69 2024-03-10            19        69          12   0.0  Orlando        19.0
#
# --------------------------------------------------
#
# Weather data for Philadelphia:
#         Date  Temperature   Humidity  Wind Speed  Rain        Cities  \
# 5 2024-01-06            19        70          14   0.0  Philadelphia
#
#    wind_chill
# 5        19.0
#
# --------------------------------------------------
#
# Weather data for Phoenix:
#         Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 4 2024-01-05            21        63          16   1.2  Phoenix        20.5
#
# --------------------------------------------------
#
# Weather data for Pittsburgh:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 64 2024-03-05            25        55          12   0.0  Pittsburgh
#
#     wind_chill
# 64        24.5
#
# --------------------------------------------------
#
# Weather data for Plano:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 68 2024-03-09            20        66          14   0.0  Plano        20.0
#
# --------------------------------------------------
#
# Weather data for Portland:
#          Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 25 2024-01-26            21        62          16   0.0  Portland        20.5
#
# --------------------------------------------------
#
# Weather data for Raleigh:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 38 2024-02-08            22        64          13   0.0  Raleigh        21.5
#
# --------------------------------------------------
#
# Weather data for Reno:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 79 2024-03-20            24        58          16   0.0   Reno        23.5
#
# --------------------------------------------------
#
# Weather data for Riverside:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 57 2024-02-27            20        66          15   0.0  Riverside        20.0
#
# --------------------------------------------------
#
# Weather data for Sacramento:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 34 2024-02-04            22        60          15   0.0  Sacramento
#
#     wind_chill
# 34        21.5
#
# --------------------------------------------------
#
# Weather data for Saint Paul:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 61 2024-03-02            22        64          14   0.0  Saint Paul
#
#     wind_chill
# 61        21.5
#
# --------------------------------------------------
#
# Weather data for Salt Lake City:
#          Date  Temperature   Humidity  Wind Speed  Rain          Cities  \
# 89 2024-03-30            22        62          15   0.0  Salt Lake City
#
#     wind_chill
# 89        21.5
#
# --------------------------------------------------
#
# Weather data for San Antonio:
#         Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 6 2024-01-07            22        62          17   0.0  San Antonio
#
#    wind_chill
# 6        21.5
#
# --------------------------------------------------
#
# Weather data for San Diego:
#         Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 7 2024-01-08            23        64          13   0.5  San Diego        22.5
#
# --------------------------------------------------
#
# Weather data for San Francisco:
#          Date  Temperature   Humidity  Wind Speed  Rain         Cities  \
# 14 2024-01-15            21        65          17   0.0  San Francisco
#
#     wind_chill
# 14        20.5
#
# --------------------------------------------------
#
# Weather data for San Jose:
#         Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 9 2024-01-10            18        72          19   0.0  San Jose        18.0
#
# --------------------------------------------------
#
# Weather data for Santa Ana:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 55 2024-02-25            22        62          14   0.0  Santa Ana        21.5
#
# --------------------------------------------------
#
# Weather data for Scottsdale:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 78 2024-03-19            23        60          14   0.0  Scottsdale
#
#     wind_chill
# 78        22.5
#
# --------------------------------------------------
#
# Weather data for Seattle:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 17 2024-01-18            19        69          20   1.0  Seattle        19.0
#
# --------------------------------------------------
#
# Weather data for Spokane:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 83 2024-03-24            22        62          14   0.1  Spokane        21.5
#
# --------------------------------------------------
#
# Weather data for St. Louis:
#          Date  Temperature   Humidity  Wind Speed  Rain     Cities  wind_chill
# 62 2024-03-03            23        61          16   0.0  St. Louis        22.5
#
# --------------------------------------------------
#
# Weather data for Stockton:
#          Date  Temperature   Humidity  Wind Speed  Rain    Cities  wind_chill
# 59 2024-02-29            24        58          18   0.0  Stockton        23.5
#
# --------------------------------------------------
#
# Weather data for Tallahassee:
#          Date  Temperature   Humidity  Wind Speed  Rain       Cities  \
# 90 2024-03-31            23        60          16   0.0  Tallahassee
#
#     wind_chill
# 90        22.5
#
# --------------------------------------------------
#
# Weather data for Tampa:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 50 2024-02-20            23        62          15   0.0  Tampa        22.5
#
# --------------------------------------------------
#
# Weather data for Tucson:
#          Date  Temperature   Humidity  Wind Speed  Rain  Cities  wind_chill
# 32 2024-02-02            19        70          18   0.2  Tucson        19.0
#
# --------------------------------------------------
#
# Weather data for Tulsa:
#          Date  Temperature   Humidity  Wind Speed  Rain Cities  wind_chill
# 45 2024-02-15            23        62          13   0.3  Tulsa        22.5
#
# --------------------------------------------------
#
# Weather data for Virginia Beach:
#          Date  Temperature   Humidity  Wind Speed  Rain          Cities  \
# 42 2024-02-12            21        63          12   0.0  Virginia Beach
#
#     wind_chill
# 42        20.5
#
# --------------------------------------------------
#
# Weather data for Washington:
#          Date  Temperature   Humidity  Wind Speed  Rain      Cities  \
# 19 2024-01-20            20        68          14   0.0  Washington
#
#     wind_chill
# 19        20.0
#
# --------------------------------------------------
#
# Weather data for Wichita:
#          Date  Temperature   Humidity  Wind Speed  Rain   Cities  wind_chill
# 48 2024-02-18            19        69          14   0.0  Wichita        19.0
#
# --------------------------------------------------
