# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [40, 41, 50, 51, 60, 61, 75]

plt.xlabel('x')
plt.ylabel('y')
plt.title('Temperature')
plt.plot(x,y , color='red',linewidth=3,linestyle='dotted')
