# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7]
max_temp = [25,21,27,35,41,32,28]
min_temp = [11,15,17,7,19,13,20]
avg_temp=[18, 18, 22, 21, 30, 22, 24]
plt.plot(max_temp,label='max')
plt.plot(min_temp,label='min')
plt.plot(avg_temp,label='avg')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.legend()
#plt.legend(loc='upper left')
#plt.legend(loc='lower left')
#plt.grid()
