# %%
import matplotlib.pyplot as plt
blood_sugar_men = [90, 110, 95, 105, 85]
blood_sugar_women = [78, 121, 88, 90, 101]
xlabel = plt.xlabel('Man/Women')
ylabel = plt.ylabel('Blood sugar level')
title = plt.title('Diabeties Data')
plt.hist([blood_sugar_men,blood_sugar_women],color=['red','green'],bins=3,rwidth=0.94,label=['Man','Women'])
plt.legend()
