# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler # Mostly used 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=11)

scalar = StandardScaler()
X_train_Scaled = scalar.fit_transform(X_train)
X_test_Scaled = scalar.transform(X_test)

# %%
clf = KNeighborsClassifier()
clf.fit(X_train_Scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
clf.score(X_test_Scaled, y_test)
# Out:
# 0.9736842105263158

# %%
single_instance = X_test_Scaled[1]

# %%
single_instance
# Out:
# array([ 1.52614234, -0.26846852,  1.56858837,  1.57461838,  1.05327932,
#         1.10776311,  1.95641027,  2.00665048,  0.77147053, -0.29240586,
#         1.20004913, -0.30277257,  0.94083243,  1.32803208, -0.98689486,
#        -0.16111294,  0.23667599,  0.16669709, -0.43089247, -0.20326946,
#         2.15893855,  0.11215199,  1.99679568,  2.39921094,  0.45705013,
#         0.80187988,  1.90308211,  1.63683226,  1.20121857,  0.43423081])

# %%
clf.predict([single_instance])
# Out:
# array([0])

# %%
y_test[1]
# Out:
# 0

# %% [markdown]
# correct prediction

# %%
clf = LogisticRegression()
clf.fit(X_train_Scaled,y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_test_Scaled,y_test)
# Out:
# 0.9824561403508771

# %%
single_instance = X_test_Scaled[1]

# %%
clf.predict([single_instance])
# Out:
# array([0])

# %%
y_test[1]
# Out:
# 0

# %% [markdown]
# correct prediction

# %% [markdown]
# there are bunch of algorithms, pracitce them
