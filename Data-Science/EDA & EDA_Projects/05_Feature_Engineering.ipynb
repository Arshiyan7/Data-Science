# %% [markdown]
# # EDA on Titanic
# ## 1. Load & Understand Data
# - Load CSV, basic inspection

# %%
#Import libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#Import dataset from seaborn 
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
print(f"rows {df.shape[0]} columns {df.shape[1]} in the dataset")
# Out:
# rows 891 columns 15 in the dataset

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.dtypes # Checking dtypes so that it is easy to change dataype of a certain column while cleaning or visualizing data
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop('class', axis=1, inplace=True) #We've encountered redundent columns pclass and class so dropping one column makes sense

# %% [markdown]
# ## Variables Description:
# - survived: Survival status of the passenger — 1 = survived, 0 = did not survive
# - pclass: Ticket class — 1 = 1st (upper class), 2 = 2nd (middle class), 3 = 3rd (working class)
# - sex: Gender of the passenger — male or female
# - age: Age of the passenger in years
# - sibsp: Number of siblings and/or spouses aboard with the passenger
# - parch: Number of parents and/or children aboard with the passenger
# - fare: Ticket fare paid by the passenger
# - who: Passenger type — man, woman, or child (based on gender and age)
# - adult_male: Boolean — True if passenger is an adult male, else False
# - deck: Cabin deck — represented by letters like A, B, C, etc.
# - embark_town: Port of embarkation — Cherbourg, Queenstown, or Southampton
# - alive: Survival status in text form — yes or no
# - alone: Boolean — True if passenger had no family aboard, else False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   who          891 non-null    object
#  9   adult_male   891 non-null    bool
#  10  deck         203 non-null    category
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.7+ KB

# %%
## Getting and visualizaing missing values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %%
plt.figure(figsize=(9,2))
sns.heatmap(df.isnull(),cmap='magma',cbar=False)
plt.title("Heatmap of missing values")
# Out:
# Text(0.5, 1.0, 'Heatmap of missing values')

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
#With tihs we can understand that why the embark_town doesn't not show on heatmap because it has very less number missing values
# Out:
# deck           77.216611
# age            19.865320
# embarked        0.224467
# embark_town     0.224467
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# who             0.000000
# adult_male      0.000000
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'who', 'adult_male', 'deck', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# # Handling missing values
# - Finding missing values
# - Handling missing values

# %%
#Show columns where values are missing  
df.columns[df.isnull().any()] #Here we use any to find if atleast any one values is null (True) in the columns
# Out:
# Index(['age', 'embarked', 'deck', 'embark_town'], dtype='object')

# %%
#Sum of total number of missing values in a columns 
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### obervations:
# - 2 NaN in embark_town
# - 177 NaN in age
# - 688 NaN in deck

# %% [markdown]
# ### filling missing values

# %%
df['age'] = df['age'].fillna(df['age'].mean())
df['embark_town'] = df['embark_town'].fillna('Unknown')
common_deck = df['deck'].mode()[0]
df['deck'] = df['deck'].fillna(common_deck)
df = df.dropna(subset=["embarked"])

# %%
df.isnull().sum() #Checking if there are still any missing values
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# 1st class passenger are older than 2nd and 2nd older than third

# %% [markdown]
# # Feature Enginerring

# %% [markdown]
# ### sibsp--parch
# - We will create a family size column where sibsp and parach will be used

# %%
df.loc[:,'Family_size'] = df['sibsp'] + df['parch']+1 
# we used +1 here because if a PERSON has sibsp = 1 and parch =  2 it makes 3 
#but it exculdes the person so that is why we are using 1 to make sure that the person gets added to making it family of 4 people

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male deck  embark_town alive  alone  Family_size
# 0        True    C  Southampton    no  False            2
# 1       False    C    Cherbourg   yes  False            2
# 2       False    C  Southampton   yes   True            1
# 3       False    C  Southampton   yes  False            2
# 4        True    C  Southampton    no   True            1

# %%
sns.set_style('darkgrid')
sns.catplot(df,x='Family_size',y='survived',kind='bar',palette='coolwarm',legend=False,hue='Family_size')
plt.ylabel("Survived")
# Out:
# Text(9.444444444444445, 0.5, 'Survived')

# %% [markdown]
# Family of **4** has more survival rate followed by **3** and **2** with the family of **6** being less likely to survive

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male deck  embark_town alive  alone  Family_size
# 0        True    C  Southampton    no  False            2
# 1       False    C    Cherbourg   yes  False            2
# 2       False    C  Southampton   yes   True            1
# 3       False    C  Southampton   yes  False            2
# 4        True    C  Southampton    no   True            1

# %%
df.loc[:,'Fsize'] = [1 if x<3 else 0 for x in df['Family_size']]
#Consider family of less than 3 as famliy

# %%
sns.set_style('darkgrid')
sns.countplot(df,x='Fsize',hue='Fsize')
# Out:
# <Axes: xlabel='Fsize', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.catplot(df,x='Fsize',y='survived',kind='bar',hue='Fsize')
plt.ylabel("Survived")
# Out:
# Text(34.12089583333333, 0.5, 'Survived')

# %%
df = pd.get_dummies(df, columns=['Fsize'],dtype=int)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male deck  embark_town alive  alone  Family_size  Fsize_0  Fsize_1
# 0        True    C  Southampton    no  False            2        0        1
# 1       False    C    Cherbourg   yes  False            2        0        1
# 2       False    C  Southampton   yes   True            1        0        1
# 3       False    C  Southampton   yes  False            2        0        1
# 4        True    C  Southampton    no   True            1        0        1

# %% [markdown]
# ### Embarked
# - we'll visulaize to get the idea how many embarks are available
# - then we'll use pd.get_dummies, to get the number of embarks in seprate columns in numerical form

# %%
sns.set_style("darkgrid")
sns.countplot(df,x='embarked',hue='embarked',legend=True)
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
df = pd.get_dummies(df, columns=['embarked'],dtype=int)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare    who  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500    man        True
# 1         1       1  female  38.0      1      0  71.2833  woman       False
# 2         1       3  female  26.0      0      0   7.9250  woman       False
# 3         1       1  female  35.0      1      0  53.1000  woman       False
# 4         0       3    male  35.0      0      0   8.0500    man        True
#
#   deck  embark_town alive  alone  Family_size  Fsize_0  Fsize_1  embarked_C  \
# 0    C  Southampton    no  False            2        0        1           0
# 1    C    Cherbourg   yes  False            2        0        1           1
# 2    C  Southampton   yes   True            1        0        1           0
# 3    C  Southampton   yes  False            2        0        1           0
# 4    C  Southampton    no   True            1        0        1           0
#
#    embarked_Q  embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %% [markdown]
# ### Pclass
# - convert pclass to to category
# - get dummies
# - visualize

# %%
sns.countplot(df, x = 'pclass',hue='pclass')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
df['pclass'] = df['pclass'].astype('category')
df = pd.get_dummies(df, columns=['pclass'],dtype=int)
df.head()
# Out:
#    survived     sex   age  sibsp  parch     fare    who  adult_male deck  \
# 0         0    male  22.0      1      0   7.2500    man        True    C
# 1         1  female  38.0      1      0  71.2833  woman       False    C
# 2         1  female  26.0      0      0   7.9250  woman       False    C
# 3         1  female  35.0      1      0  53.1000  woman       False    C
# 4         0    male  35.0      0      0   8.0500    man        True    C
#
#    embark_town  ...  alone  Family_size  Fsize_0  Fsize_1  embarked_C  \
# 0  Southampton  ...  False            2        0        1           0
# 1    Cherbourg  ...  False            2        0        1           1
# 2  Southampton  ...   True            1        0        1           0
# 3  Southampton  ...  False            2        0        1           0
# 4  Southampton  ...   True            1        0        1           0
#
#    embarked_Q  embarked_S  pclass_1  pclass_2  pclass_3
# 0           0           1         0         0         1
# 1           0           0         1         0         0
# 2           0           1         0         0         1
# 3           0           1         1         0         0
# 4           0           1         0         0         1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Sex
# - convert pclass to to category
# - get dummies
# - visualize

# %%
df['sex'] = df['sex'].astype('category')
df = pd.get_dummies(df, columns=['sex'],dtype=int)
df.head()
# Out:
#    survived   age  sibsp  parch     fare    who  adult_male deck  embark_town  \
# 0         0  22.0      1      0   7.2500    man        True    C  Southampton
# 1         1  38.0      1      0  71.2833  woman       False    C    Cherbourg
# 2         1  26.0      0      0   7.9250  woman       False    C  Southampton
# 3         1  35.0      1      0  53.1000  woman       False    C  Southampton
# 4         0  35.0      0      0   8.0500    man        True    C  Southampton
#
#   alive  ...  Fsize_0  Fsize_1  embarked_C  embarked_Q  embarked_S  pclass_1  \
# 0    no  ...        0        1           0           0           1         0
# 1   yes  ...        0        1           1           0           0         1
# 2   yes  ...        0        1           0           0           1         0
# 3   yes  ...        0        1           0           0           1         1
# 4    no  ...        0        1           0           0           1         0
#
#    pclass_2  pclass_3  sex_female  sex_male
# 0         0         1           0         1
# 1         0         0           1         0
# 2         0         1           1         0
# 3         0         0           1         0
# 4         0         1           0         1
#
# [5 rows x 22 columns]

# %% [markdown]
# Cannot visualize because we want to visualize both sex_female and sex_male in same x-axis which is not possible, but maybe we do it in future
# tutorials,
# - This marks the **END** of Feature engineering and possibly EDA tutorials
# next up:
# - small projects to strengthen EDA
