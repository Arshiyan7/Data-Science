# %%
#Note: All code snippets are originally written by the user and professionally formatted for readability and clarity by ChatGPT.

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset = sns.load_dataset('penguins')

# Display dataset info
print("="*40)
print("📌 DATASET INFORMATION")
print("="*40)
print(dataset.info())

# Display first 5 rows
print("\n" + "="*40)
print("🔍 FIRST 5 ROWS OF THE DATASET")
print("="*40)
print(dataset.head())

# Display last 5 rows
print("\n" + "="*40)
print("📌 LAST 5 ROWS OF THE DATASET")
print("="*40)
print(dataset.tail())

# Display basic statistics
print("\n" + "="*40)
print("📊 BASIC STATISTICS")
print("="*40)
print(dataset.describe())
# Out:
# ...
# 📌 DATASET INFORMATION
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# None
#
# ...
# 🔍 FIRST 5 ROWS OF THE DATASET
# ...
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# ...

# %%
# Check for missing values
missing_values = dataset.isnull().sum()
print("\n" + "="*40)
print("❗ MISSING VALUES IN DATASET")
print("="*40)
print(missing_values)

# Dropping missing values
dataset_cleaned = dataset.dropna()

# Verify if missing values are handled
print("\n" + "="*40)
print("✅ DATA CLEANED! (Missing values handled)")
print("="*40)
print(dataset_cleaned.isnull().sum())
# Out:
# ...
# ❗ MISSING VALUES IN DATASET
# ...
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
#
# ...
# ✅ DATA CLEANED! (Missing values handled)
# ...
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=dataset_copy['body_mass_g'],bins=30,kde=True,color="royalblue")
plt.title("Distribution of Body Mass (g)", fontsize=14)
plt.xlabel("Body Mass (g)")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
sns.set_style("whitegrid")

joint_plot = sns.jointplot(
    data=dataset_copy,
    x="flipper_length_mm",
    y="body_mass_g",
    kind="scatter",
    color="crimson", 
    height=7,  
)
joint_plot.fig.suptitle("Relationship between Flipper Length and Body Mass", fontsize=14, fontweight='bold', y=1.02)

# Show the plot
plt.show()

# %%
sns.ecdfplot(data=dataset_copy,x='flipper_length_mm',color='r',linewidth=2,linestyle='dotted',hue='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Proportion'>
